# %%
#importing libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
from google.colab import drive
from scipy import stats

warnings.filterwarnings('ignore')
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Setup Enviornment 

DATASET_PATH = "/content/gdrive/MyDrive/Estudos/Pos-graduacao - Ciencia de Dados e  Analytics/Sprints/sprint I - Analise de salarios cientista de dados/data_science_job_market_analysis/Dataset"
os.chdir(DATASET_PATH)

# %%
h1bdata_df = pd.read_csv("EUA/USA_data_science_jobs_h1bdata.csv", delimiter=',')
glassdoor_df = pd.read_csv("Jobs_descriptions_EUA/DataScientist_glassdoor.csv")

# %% [markdown]
# ## Cleaning h1bdata dataset

# %%
h1bdata_df.head(20)
# Out:
#     Unnamed: 0                            company           title  salary  \
# 0            0  FORTRESS INFORMATION SECURITY LLC  DATA SCIENTIST  45,980
# 1            1              PERCOLATA CORPORATION  DATA SCIENTIST  46,060
# 2            2               MY LIFE REGISTRY LLC  DATA SCIENTIST  47,960
# 3            3               MY LIFE REGISTRY LLC  DATA SCIENTIST  47,960
# 4            4     BIG DATA ANALYTICS TRADING INC  DATA SCIENTIST  50,000
# 5            5                    YONO HEALTH INC  DATA SCIENTIST  50,220
# 6            6                          EONUM INC  DATA SCIENTIST  51,100
# 7            7                          EONUM INC  DATA SCIENTIST  51,100
# 8            8                          EONUM INC  DATA SCIENTIST  51,100
# 9            9                OPEN DATA GROUP INC  DATA SCIENTIST  51,860
# 10          10                              \n \n             NaN     NaN
# 11          11           SRIVEN SYSTEMS OF TX INC  DATA SCIENTIST  52,000
# 12          12   NECTO-NET CONTACT MANAGEMENT INC  DATA SCIENTIST  52,300
# 13          13             THE BALMORAL GROUP LLC  DATA SCIENTIST  58,920
# 14          14           BLINKAI TECHNOLOGIES INC  DATA SCIENTIST  59,340
# 15          15            MESONS TECHNOLOGIES LLC  DATA SCIENTIST  60,000
# 16          16          ADECCO GROUP NA/MODIS INC  DATA SCIENTIST  60,000
# 17          17                           LTLW INC  DATA SCIENTIST  60,080
# 18          18                      ARIES APP INC  DATA SCIENTIST  60,140
# 19          19   CLINPHARMA CLINICAL RESEARCH LLC  DATA SCIENTIST  60,360
#
#             location        date
# 0        ORLANDO, FL  04/09/2020
# 1      PALO ALTO, CA  03/18/2016
# 2       FORT LEE, NJ  02/18/2015
# 3       FORT LEE, NJ  02/18/2015
# 4    JOHNS CREEK, GA  03/16/2017
# 5      SUNNYVALE, CA  02/28/2017
# 6         IRVINE, CA  04/08/2021
# 7         IRVINE, CA  04/12/2021
# 8         IRVINE, CA  04/16/2021
# 9        CHICAGO, IL  02/28/2019
# 10               NaN         NaN
# 11       MADISON, WI  03/07/2018
# 12       HOUSTON, TX  03/16/2017
# 13   WINTER PARK, FL  03/21/2018
# 14        BOSTON, MA  03/12/2019
# 15  JACKSONVILLE, FL  05/18/2022
# 16      DEARBORN, MI  06/13/2017
# 17   LOS ANGELES, CA  04/02/2021
# 18      BELLEVUE, WA  03/06/2017
# 19    WILMINGTON, DE  03/10/2017

# %%
h1bdata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82431 entries, 0 to 82430
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  82431 non-null  int64
#  1   company     82430 non-null  object
#  2   title       82396 non-null  object
#  3   salary      82396 non-null  object
#  4   location    82396 non-null  object
#  5   date        82396 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 3.8+ MB

# %% [markdown]
# ### Cleaning Blank lines

# %%
h1bdata_clean_df = h1bdata_df.dropna(how='any')
h1bdata_clean_df.head(20)
# Out:
#     Unnamed: 0                            company           title  salary  \
# 0            0  FORTRESS INFORMATION SECURITY LLC  DATA SCIENTIST  45,980
# 1            1              PERCOLATA CORPORATION  DATA SCIENTIST  46,060
# 2            2               MY LIFE REGISTRY LLC  DATA SCIENTIST  47,960
# 3            3               MY LIFE REGISTRY LLC  DATA SCIENTIST  47,960
# 4            4     BIG DATA ANALYTICS TRADING INC  DATA SCIENTIST  50,000
# 5            5                    YONO HEALTH INC  DATA SCIENTIST  50,220
# 6            6                          EONUM INC  DATA SCIENTIST  51,100
# 7            7                          EONUM INC  DATA SCIENTIST  51,100
# 8            8                          EONUM INC  DATA SCIENTIST  51,100
# 9            9                OPEN DATA GROUP INC  DATA SCIENTIST  51,860
# 11          11           SRIVEN SYSTEMS OF TX INC  DATA SCIENTIST  52,000
# 12          12   NECTO-NET CONTACT MANAGEMENT INC  DATA SCIENTIST  52,300
# 13          13             THE BALMORAL GROUP LLC  DATA SCIENTIST  58,920
# 14          14           BLINKAI TECHNOLOGIES INC  DATA SCIENTIST  59,340
# 15          15            MESONS TECHNOLOGIES LLC  DATA SCIENTIST  60,000
# 16          16          ADECCO GROUP NA/MODIS INC  DATA SCIENTIST  60,000
# 17          17                           LTLW INC  DATA SCIENTIST  60,080
# 18          18                      ARIES APP INC  DATA SCIENTIST  60,140
# 19          19   CLINPHARMA CLINICAL RESEARCH LLC  DATA SCIENTIST  60,360
# 20          20                      DSFEDERAL INC  DATA SCIENTIST  60,420
#
#             location        date
# 0        ORLANDO, FL  04/09/2020
# 1      PALO ALTO, CA  03/18/2016
# 2       FORT LEE, NJ  02/18/2015
# 3       FORT LEE, NJ  02/18/2015
# 4    JOHNS CREEK, GA  03/16/2017
# 5      SUNNYVALE, CA  02/28/2017
# 6         IRVINE, CA  04/08/2021
# 7         IRVINE, CA  04/12/2021
# 8         IRVINE, CA  04/16/2021
# 9        CHICAGO, IL  02/28/2019
# 11       MADISON, WI  03/07/2018
# 12       HOUSTON, TX  03/16/2017
# 13   WINTER PARK, FL  03/21/2018
# 14        BOSTON, MA  03/12/2019
# 15  JACKSONVILLE, FL  05/18/2022
# 16      DEARBORN, MI  06/13/2017
# 17   LOS ANGELES, CA  04/02/2021
# 18      BELLEVUE, WA  03/06/2017
# 19    WILMINGTON, DE  03/10/2017
# 20     ROCKVILLE, MD  03/05/2019

# %%
h1bdata_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82395 entries, 0 to 82430
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  82395 non-null  int64
#  1   company     82395 non-null  object
#  2   title       82395 non-null  object
#  3   salary      82395 non-null  object
#  4   location    82395 non-null  object
#  5   date        82395 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 4.4+ MB

# %% [markdown]
# ### Looking for any line with "null"

# %%
h1bdata_clean_df.isnull().sum()
# Out:
# Unnamed: 0    0
# company       0
# title         0
# salary        0
# location      0
# date          0
# dtype: int64

# %%
h1bdata_clean_df.isin(["null"]).sum()
# Out:
# Unnamed: 0    0
# company       0
# title         0
# salary        0
# location      0
# date          0
# dtype: int64

# %%
h1bdata_clean_df['title'].value_counts()
# Out:
# BUSINESS ANALYST    39586
# DATA SCIENTIST      16953
# DATA ANALYST        11685
# DATA ENGINEER       10887
# DATA ARCHITECT       1582
# STATISTICIAN         1041
# BI ANALYST            661
# Name: title, dtype: int64

# %% [markdown]
# ### Converting Salaries to right format

# %%
#one extra thing, we have need getting rid of commas:
h1bdata_clean_df ["salary"] = h1bdata_clean_df ["salary"].apply(lambda x: x.replace(",",""))

# %%
h1bdata_clean_df ["salary"] = h1bdata_clean_df ["salary"].astype(np.float64)

# %%
h1bdata_clean_df ["salary"]
# Out:
# 0         45980.0
# 1         46060.0
# 2         47960.0
# 3         47960.0
# 4         50000.0
#            ...
# 82426    183000.0
# 82427    200476.0
# 82428    200476.0
# 82429    216000.0
# 82430    225000.0
# Name: salary, Length: 82395, dtype: float64

# %% [markdown]
# ## Outliers Elimination

# %% [markdown]
# ### Test With z_score( |z| < 3)

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data=h1bdata_clean_df, y="salary",x='title')
plt.ylim([0,2.5e5])
# Out:
# (0.0, 250000.0)

# %%
h1bdata_clean_df['salary'].plot(kind='density')
plt.xlim([0,3e5])
# Out:
# (0.0, 300000.0)

# %%
DS_JOBS = ["DATA SCIENTIST","DATA ENGINEER","DATA ANALYST","DATA ARCHITECT","BI ANALYST","BUSINESS ANALYST","STATISTICIAN"]
colors = ['green','red','blue','yellow','magenta','lime','cyan']
fig, axs = plt.subplots(1,7, figsize=(40,10))

for (i,job) in zip(range(0, len(DS_JOBS) ), DS_JOBS):
  tmp_df = h1bdata_clean_df[ h1bdata_clean_df['title']== job ]['salary']
  z_score = np.abs(stats.zscore(tmp_df))
  outlier_free = tmp_df[ (z_score < 3)]
  outlier_free.plot(kind='density', ax= axs[i],color=colors[i])
  plt.title(f"{job} salary distribution")
  #plt.xlim([0,3e5])

# %%
fig, axs = plt.subplots(1,7, figsize=(20,10))

for (i,job) in zip(range(0, len(DS_JOBS) ), DS_JOBS):
  tmp_df = h1bdata_clean_df[ h1bdata_clean_df['title']== job ]['salary']
  z_score = np.abs(stats.zscore(tmp_df))
  outlier_free = tmp_df[ (z_score < 3)]
  outlier_free.plot(kind='box', ax= axs[i],color=colors[i])
  plt.title(f"{job} salary distribution")
  #plt.xlim([0,3e5])

# %%
fig, axs = plt.subplots(1,7, figsize=(20,10))

for (i,job) in zip(range(0, len(DS_JOBS) ), DS_JOBS):
  tmp_df = h1bdata_clean_df[ h1bdata_clean_df['title']== job ]['salary']
  z_score = np.abs(stats.zscore(tmp_df))
  outlier_free = tmp_df#[ (z_score < 3)]
  outlier_free.plot(kind='box', ax= axs[i],color=colors[i])
  plt.title(f"{job} salary distribution")
  #plt.xlim([0,3e5])

# %% [markdown]
# ### Test With Interquantile Range

# %%
colors = ['green','red','blue','yellow','magenta','lime','cyan']
fig, axs = plt.subplots(1,7, figsize=(40,10))



for (i,job) in zip(range(0, len(DS_JOBS) ), DS_JOBS):
  tmp_df = h1bdata_clean_df[ h1bdata_clean_df['title']== job ][['salary']]

  Q1 = tmp_df.quantile(0.25)
  Q3 = tmp_df.quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5*IQR
  upper_bound = Q3 + 1.5*IQR
 
 
  outlier_free = tmp_df[~((tmp_df < (Q1 - 1.5 * IQR)) |(tmp_df > (Q3 + 1.5 * IQR))).any(axis=1) ]

  outlier_free.plot(kind='density', ax= axs[i],color=colors[i])
  plt.title(f"{job} salary distribution")
  #plt.xlim([0,3e5])

# %%
fig, axs = plt.subplots(1,7, figsize=(20,10))
for (i,job) in zip(range(0, len(DS_JOBS) ), DS_JOBS):
  tmp_df = h1bdata_clean_df[ h1bdata_clean_df['title']== job ][['salary']]

  Q1 = tmp_df.quantile(0.25)
  Q3 = tmp_df.quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5*IQR
  upper_bound = Q3 + 1.5*IQR
 
 
  outlier_free = tmp_df[~((tmp_df < (Q1 - 1.5 * IQR)) |(tmp_df > (Q3 + 1.5 * IQR))).any(axis=1) ]

  outlier_free.plot(kind='box', ax= axs[i],color=colors[i])
  plt.title(f"{job} salary distribution")
  #plt.xlim([0,3e5])

# %%
fig, axs = plt.subplots(1,7, figsize=(20,10))
for (i,job) in zip(range(0, len(DS_JOBS) ), DS_JOBS):
  tmp_df = h1bdata_clean_df[ h1bdata_clean_df['title']== job ][['salary']]

  Q1 = tmp_df.quantile(0.25)
  Q3 = tmp_df.quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5*IQR
  upper_bound = Q3 + 1.5*IQR
 
 
  outlier_free = tmp_df#[~((tmp_df < (Q1 - 1.5 * IQR)) |(tmp_df > (Q3 + 1.5 * IQR))).any(axis=1) ]

  outlier_free.plot(kind='box', ax= axs[i],color=colors[i])
  plt.title(f"{job} salary distribution")
  #plt.xlim([0,3e5])

# %%
outlier_free_df = pd.DataFrame({}, columns = h1bdata_clean_df.columns)
for (i,job) in zip(range(0, len(DS_JOBS) ), DS_JOBS):
  tmp_df = h1bdata_clean_df[ h1bdata_clean_df['title']== job ][['salary']]

  Q1 = tmp_df.quantile(0.25)
  Q3 = tmp_df.quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5*IQR
  upper_bound = Q3 + 1.5*IQR
  outlier_free_for_a_job = tmp_df[~((tmp_df < (Q1 - 1.5 * IQR)) |(tmp_df > (Q3 + 1.5 * IQR))).any(axis=1) ]
  #cocat lines with no outlines per JOB
  tmp_outlier_free = h1bdata_clean_df[ h1bdata_clean_df['title']== job ][~((tmp_df < (Q1 - 1.5 * IQR)) |(tmp_df > (Q3 + 1.5 * IQR))).any(axis=1) ]
  outlier_free_df = pd.concat([outlier_free_df,tmp_outlier_free])

# %%
len(outlier_free_df)
# Out:
# 80150

# %%
len(h1bdata_clean_df)
# Out:
# 82395

# %%
outlier_free_df['title'].value_counts()
# Out:
# BUSINESS ANALYST    38318
# DATA SCIENTIST      16770
# DATA ANALYST        11277
# DATA ENGINEER       10622
# DATA ARCHITECT       1555
# STATISTICIAN         1000
# BI ANALYST            608
# Name: title, dtype: int64

# %%
fig, axs = plt.subplots(1,7, figsize=(20,10))
for (i,job) in zip(range(0, len(DS_JOBS) ), DS_JOBS):
 
 
  outlier_free = outlier_free_df[outlier_free_df['title']== job]['salary']

  outlier_free.plot(kind='box', ax= axs[i],color=colors[i])
  plt.title(f"{job} salary distribution")
  #plt.xlim([0,3e5])

# %%
h1bdata_clean_df = outlier_free_df

# %%
h1bdata_clean_df
# Out:
#        Unnamed: 0                            company           title  \
# 0         45980.0  FORTRESS INFORMATION SECURITY LLC  DATA SCIENTIST
# 1         46060.0              PERCOLATA CORPORATION  DATA SCIENTIST
# 2         47960.0               MY LIFE REGISTRY LLC  DATA SCIENTIST
# 3         47960.0               MY LIFE REGISTRY LLC  DATA SCIENTIST
# 4         50000.0     BIG DATA ANALYTICS TRADING INC  DATA SCIENTIST
# ...           ...                                ...             ...
# 82389     82389.0       TECHDATA SERVICE COMPANY LLC    STATISTICIAN
# 82390     82390.0       TECHDATA SERVICE COMPANY LLC    STATISTICIAN
# 82391     82391.0         WELLS FARGO SECURITIES LLC    STATISTICIAN
# 82392     82392.0       ARION CAPITAL MANAGEMENT LLC    STATISTICIAN
# 82393     82393.0                   TIGERMED-BDM INC    STATISTICIAN
#
#          salary         location        date
# 0       45980.0      ORLANDO, FL  04/09/2020
# 1       46060.0    PALO ALTO, CA  03/18/2016
# 2       47960.0     FORT LEE, NJ  02/18/2015
# 3       47960.0     FORT LEE, NJ  02/18/2015
# 4       50000.0  JOHNS CREEK, GA  03/16/2017
# ...         ...              ...         ...
# 82389  135000.0     SOMERSET, NJ  08/27/2022
# 82390  135000.0     SOMERSET, NJ  08/26/2022
# 82391  135000.0    CHARLOTTE, NC  10/26/2015
# 82392  135000.0     BENSALEM, PA  03/13/2019
# 82393  135869.0     SOMERSET, NJ  06/09/2018
#
# [80150 rows x 6 columns]

# %% [markdown]
# ## Splitting Columns

# %%
h1bdata_clean_df['location']
# Out:
# 0            ORLANDO, FL
# 1          PALO ALTO, CA
# 2           FORT LEE, NJ
# 3           FORT LEE, NJ
# 4        JOHNS CREEK, GA
#               ...
# 82389       SOMERSET, NJ
# 82390       SOMERSET, NJ
# 82391      CHARLOTTE, NC
# 82392       BENSALEM, PA
# 82393       SOMERSET, NJ
# Name: location, Length: 80150, dtype: object

# %%
 h1bdata_clean_df[['city', 'state']]  =  h1bdata_clean_df['location'].str.split(', ', expand=True).iloc[:,:-1]

h1bdata_clean_df.drop('location', axis = 1 , inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-ff55a928cd77> in <cell line: 1>()
# ----> 1 h1bdata_clean_df[['city', 'state']]  =  h1bdata_clean_df['location'].str.split(', ', expand=True).iloc[:,:-1]
#       2
#       3 h1bdata_clean_df.drop('location', axis = 1 , inplace= True)
#       4 h1bdata_clean_df
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'location'

# %%
h1bdata_clean_df['state'].unique()
# Out:
# array(['FL', 'CA', 'NJ', 'GA', 'IL', 'WI', 'TX', 'MA', 'MI', 'WA', 'DE',
#        'MD', 'NY', 'VA', 'MO', 'NC', 'TN', 'MN', 'IN', 'PA', 'OH', 'IA',
#        'AZ', 'CO', 'UT', 'LA', 'OK', 'AR', 'OR', 'KS', 'NH', 'NV', 'DC',
#        'NE', 'CT', 'PR', 'KY', 'SC', 'AL', 'NM', 'MS', 'ND', 'RI', 'ID',
#        'IL 60654', 'HI', 'WY', 'SD', 'VT', 'ME', 'SHOREVIEW', 'NJ 07642',
#        'D.C.', 'WV', 'NY,', 'VT.', 'SAN RAMON,', 'ATLANTA', 'MT',
#        'CA 95134', 'TX 77002', '5TH FL', 'AK', 'D.C', 'DC 20006', 'VI',
#        'MINNEAPOLIS', 'ETS DRIVE', '', 'MO 63105', 'WASHINGTON',
#        'NEW YORK'], dtype=object)

# %%
pd.DataFrame(h1bdata_clean_df[['state']].value_counts())
# Out:
#                 0
# state
# CA          16514
# TX           8191
# NY           7316
# NJ           6932
# IL           3912
# ...           ...
# MO 63105        1
# SAN RAMON,      1
# 5TH FL          1
# NEW YORK        1
#                 1
#
# [72 rows x 1 columns]

# %%
pd.DataFrame(h1bdata_clean_df[['city']].value_counts())
# Out:
#                   0
# city
# NEW YORK       5259
# SAN FRANCISCO  3074
# CHICAGO        1657
# MENLO PARK     1551
# ATLANTA        1545
# ...             ...
# MARIETTA,         1
# MARGATE           1
# MARCH ARB         1
# MARBLEHEAD        1
# Â SEATTLE         1
#
# [2719 rows x 1 columns]

# %% [markdown]
# ### Map and replace

# %%
map = {
    "DC 20006": "WA",
    "CA 95134": "CA",
    "WASHINGTON": "WA",
    "VT.": "VT"	,
    "TX 77002": "TX",
    "NJ 07642": "NJ",
    "IL 60654": "IL",
    "SHOREVIEW":"MN",
    "MINNEAPOLIS": "MN",
    "MO 63105":"MO",
    "SAN RAMON,":	"CA",
    "5TH FL": "FL",
    "NEW YORK": "NY",
    'NY,': "NY",
    "ETS DRIVE":"unkown",
    "D.C.":"WA",
    "D.C":"WA",
    "ATLANTA":"GA"

}

# %%
h1bdata_clean_df['state'] = h1bdata_clean_df['state'].replace(map)
h1bdata_clean_df['state'] = h1bdata_clean_df[  h1bdata_clean_df['state'] !='unkown']['state']

# %% [markdown]
# ## Convert to date columns to date in right format

# %%
h1bdata_clean_df['date'] = pd.to_datetime(h1bdata_clean_df['date'], format ='%m/%d/%Y').dt.strftime('%d/%m/%Y')

# %% [markdown]
# ## Conteplating the work of art

# %%
h1bdata_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80150 entries, 0 to 82393
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  80150 non-null  float64
#  1   company     80150 non-null  object
#  2   title       80150 non-null  object
#  3   salary      80150 non-null  float64
#  4   date        80150 non-null  object
#  5   city        80150 non-null  object
#  6   state       80149 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 6.9+ MB

# %%
h1bdata_clean_df.head(30)
# Out:
#     Unnamed: 0                            company           title   salary  \
# 0      45980.0  FORTRESS INFORMATION SECURITY LLC  DATA SCIENTIST  45980.0
# 1      46060.0              PERCOLATA CORPORATION  DATA SCIENTIST  46060.0
# 2      47960.0               MY LIFE REGISTRY LLC  DATA SCIENTIST  47960.0
# 3      47960.0               MY LIFE REGISTRY LLC  DATA SCIENTIST  47960.0
# 4      50000.0     BIG DATA ANALYTICS TRADING INC  DATA SCIENTIST  50000.0
# 5      50220.0                    YONO HEALTH INC  DATA SCIENTIST  50220.0
# 6      51100.0                          EONUM INC  DATA SCIENTIST  51100.0
# 7      51100.0                          EONUM INC  DATA SCIENTIST  51100.0
# 8      51100.0                          EONUM INC  DATA SCIENTIST  51100.0
# 9      51860.0                OPEN DATA GROUP INC  DATA SCIENTIST  51860.0
# 11     52000.0           SRIVEN SYSTEMS OF TX INC  DATA SCIENTIST  52000.0
# 12     52300.0   NECTO-NET CONTACT MANAGEMENT INC  DATA SCIENTIST  52300.0
# 13     58920.0             THE BALMORAL GROUP LLC  DATA SCIENTIST  58920.0
# 14     59340.0           BLINKAI TECHNOLOGIES INC  DATA SCIENTIST  59340.0
# 15     60000.0            MESONS TECHNOLOGIES LLC  DATA SCIENTIST  60000.0
# 16     60000.0          ADECCO GROUP NA/MODIS INC  DATA SCIENTIST  60000.0
# 17     60080.0                           LTLW INC  DATA SCIENTIST  60080.0
# 18     60140.0                      ARIES APP INC  DATA SCIENTIST  60140.0
# 19     60360.0   CLINPHARMA CLINICAL RESEARCH LLC  DATA SCIENTIST  60360.0
# 20     60420.0                      DSFEDERAL INC  DATA SCIENTIST  60420.0
# 21     60420.0                      DSFEDERAL INC  DATA SCIENTIST  60420.0
# 22     62000.0                     CYBERXDATA LLC  DATA SCIENTIST  62000.0
# 23     62000.0                          EONUM INC  DATA SCIENTIST  62000.0
# 24     62000.0                 ALLAZO HEALTH CORP  DATA SCIENTIST  62000.0
# 25     62060.0                     TEKSYSTEMS INC  DATA SCIENTIST  62060.0
# 26     62980.0             A&Z PHARMACEUTICAL INC  DATA SCIENTIST  62980.0
# 27     63720.0                     TEKSYSTEMS INC  DATA SCIENTIST  63720.0
# 28     65080.0                         CHUMMY LLC  DATA SCIENTIST  65080.0
# 29     65500.0          ADECCO GROUP NA/MODIS INC  DATA SCIENTIST  65500.0
# 30     65500.0          ADECCO GROUP NA/MODIS INC  DATA SCIENTIST  65500.0
#
#           date          city state
# 0   09/04/2020       ORLANDO    FL
# 1   18/03/2016     PALO ALTO    CA
# 2   18/02/2015      FORT LEE    NJ
# 3   18/02/2015      FORT LEE    NJ
# 4   16/03/2017   JOHNS CREEK    GA
# 5   28/02/2017     SUNNYVALE    CA
# 6   08/04/2021        IRVINE    CA
# 7   12/04/2021        IRVINE    CA
# 8   16/04/2021        IRVINE    CA
# 9   28/02/2019       CHICAGO    IL
# 11  07/03/2018       MADISON    WI
# 12  16/03/2017       HOUSTON    TX
# 13  21/03/2018   WINTER PARK    FL
# 14  12/03/2019        BOSTON    MA
# 15  18/05/2022  JACKSONVILLE    FL
# 16  13/06/2017      DEARBORN    MI
# 17  02/04/2021   LOS ANGELES    CA
# 18  06/03/2017      BELLEVUE    WA
# 19  10/03/2017    WILMINGTON    DE
# 20  05/03/2019     ROCKVILLE    MD
# 21  08/03/2019     ROCKVILLE    MD
# 22  20/03/2019        NEWTON    MA
# 23  30/07/2021        IRVINE    CA
# 24  07/03/2016      NEW YORK    NY
# 25  14/03/2016      DEARBORN    MI
# 26  10/03/2020     HAUPPAUGE    NY
# 27  16/03/2016      DEARBORN    MI
# 28  08/03/2016    BURLINGAME    CA
# 29  19/03/2019      DEARBORN    MI
# 30  05/07/2018      DEARBORN    MI
